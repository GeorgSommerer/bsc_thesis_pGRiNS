# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scanpy as sc
import anndata as ad

import os

from grins import get_pert_data

# %% [markdown]
# # Retrieve Steady State Solutions as AnnData Object:

# %%
topo = "dorothea_tf2_abc"
replicate = 1
is_racipe = True # Whether or not Racipe or Ising data should be loaded
is_discrete = False # If Ising: whether or not sync data should be loaded

# %%
import importlib
importlib.reload(get_pert_data)
# Specify file path:
if is_racipe:
    path_to_data = f"Data/SimulResults_Racipe/{topo}/00{replicate}/{topo}_steadystate_solutions_00{replicate}"
else:
    if is_sync:
        path_to_data = f"Data/SimulResults_Ising/{topo}/{replicate}/{topo}_sync_ising_results"
    else:
        path_to_data = f"Data/SimulResults_Ising/{topo}/{replicate}/{topo}_async_ising_results"

# Get AnnData object:
if not os.path.isfile(f"{path_to_data}.h5ad"):
    grins_data = get_pert_data.grins_to_adata(path_to_data,is_racipe, is_discrete)
else:
    print("Reading h5ad file...")
    grins_data = sc.read_h5ad(f"{path_to_data}.h5ad")
# Out:
# Read Data/SimulResults_Racipe/dorothea_tf2_abc/001/dorothea_tf2_abc_steadystate_solutions_001.parquet...
# Create AnnData object...
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# Normalize Data...
# Calculate QC metrics...
# Save the AnnData object to Data/SimulResults_Racipe/dorothea_tf2_abc/001/dorothea_tf2_abc_steadystate_solutions_001.h5ad...
