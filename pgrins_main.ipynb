# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import scanpy as sc
import anndata as ad

import os

from grins import get_pert_data

# %% [markdown]
# # Retrieve Steady State Solutions as AnnData Object:

# %%
topo = "dorothea_tf2_abc"
replicate = 1
is_racipe = False # Whether or not Racipe or Ising data should be loaded
is_sync = True # If Ising: whether or not sync data should be loaded

# %%
# Specify file path:
if is_racipe:
    path_to_data = f"Data/SimulResults_Racipe/{topo}/00{replicate}/{topo}_steadystate_solutions_{replicate}"
else:
    if is_sync:
        path_to_data = f"Data/SimulResults_Ising/{topo}/{replicate}/{topo}_sync_ising_results"
    else:
        path_to_data = f"Data/SimulResults_Ising/{topo}/{replicate}/{topo}_async_ising_results"

# Get AnnData object:
if not os.path.isfile(f"{path_to_data}.h5ad"):
    grins_data = get_pert_data.steadystate_to_adata(path_to_data,is_racipe)
else:
    print("Reading h5ad file...")
    grins_data = sc.read_h5ad(f"{path_to_data}.h5ad")
# Out:
# Read the Data/SimulResults_Ising/dorothea_tf2_abc/1/dorothea_tf2_abc_sync_ising_results.parquet...
#        Step  Initnum  AHR|AR|ARID2|ARID3A|ARNT|ARNTL|ASCL1|ATF1  \
# 0         0        0                                        121
# 1      2590        0                                         95
# 2         0        1                                        134
# 3      2590        1                                        205
# 4         0        2                                        191
# ...     ...      ...                                        ...
# 32763  2590    16381                                        205
# 32764     0    16382                                        188
# 32765  2590    16382                                        222
# 32766     0    16383                                        195
# 32767  2590    16383                                        205
#
#        ATF2|ATF3|ATF4|ATF6|ATF7|BACH1|BACH2|BATF  \
# ...
